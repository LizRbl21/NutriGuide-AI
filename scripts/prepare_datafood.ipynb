# %%
import pandas as pd

# %%
food_1 = pd.read_csv("../data/FOOD-DATA-GROUP1.csv")
food_1 = food_1.drop(["Unnamed: 0", "Unnamed: 0.1", "Nutrition Density"], axis=1)
food_1.head()
# Out:
#                                food  Caloric Value   Fat  Saturated Fats  \
# 0                      cream cheese             51   5.0             2.9
# 1                 neufchatel cheese            215  19.4            10.9
# 2  requeijao cremoso light catupiry             49   3.6             2.3
# 3                    ricotta cheese             30   2.0             1.3
# 4              cream cheese low fat             30   2.3             1.4
#
#    Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  Sugars  Protein  \
# 0                   1.3                 0.200            0.8   0.500      0.9
# 1                   4.9                 0.800            3.1   2.700      7.8
# 2                   0.9                 0.000            0.9   3.400      0.8
# 3                   0.5                 0.002            1.5   0.091      1.5
# 4                   0.6                 0.042            1.2   0.900      1.2
#
# ...

# %%
food_2 = pd.read_csv("../data/FOOD-DATA-GROUP2.csv")
food_2 = food_2.drop(["Unnamed: 0", "Unnamed: 0.1", "Nutrition Density"], axis=1)
food_2.head()
# Out:
#                    food  Caloric Value   Fat  Saturated Fats  \
# 0                eggnog            224  10.6             6.6
# 1            beer light             96   0.0             0.0
# 2        beer budweiser             12   0.0             0.0
# 3   weizenbier erdinger            220  18.0            13.0
# 4  beer light budweiser              9   0.0             0.0
#
#    Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  Sugars  Protein  \
# 0                   3.3                   0.5           20.4    20.4   11.600
# 1                   0.0                   0.0            5.4     0.3    0.800
# 2                   0.0                   0.0            0.9     0.0    0.100
# 3                   1.0                   0.0            0.0     0.0    0.000
# 4                   0.0                   0.0            0.4     0.0    0.066
#
#    Dietary Fiber  ...  Vitamin K  Calcium  Copper   Iron  Magnesium  \
# ...

# %%
food_3 = pd.read_csv("../data/FOOD-DATA-GROUP3.csv")
food_3 = food_3.drop(["Unnamed: 0", "Unnamed: 0.1", "Nutrition Density"], axis=1)
food_3.head()
# Out:
#                food  Caloric Value    Fat  Saturated Fats  \
# 0         nectarine             66  0.500           0.066
# 1    kiwifruit gold             51  0.200           0.008
# 2  prickly pear raw              8  0.072           0.000
# 3         pineapple             45  0.100           0.074
# 4             rowan            253  4.600           0.600
#
#    Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  Sugars  Protein  \
# 0                 0.100                 0.200           15.8    11.8    1.600
# 1                 0.099                 0.051           12.8    10.0    0.800
# 2                 0.000                 0.000            1.9     0.2    0.001
# 3                 0.001                 0.087           11.8     8.9    0.500
# 4                 0.000                 0.000           54.5    32.1    5.200
#
#    Dietary Fiber  ...  Vitamin K  Calcium  Copper   Iron  Magnesium  \
# 0            2.6  ...      1.200    0.081   9.000  0.100        0.4
# ...

# %%
food_4 = pd.read_csv("../data/FOOD-DATA-GROUP4.csv")
food_4 = food_4.drop(["Unnamed: 0", "Unnamed: 0.1", "Nutrition Density"], axis=1)
food_4.head()
# Out:
#                          food  Caloric Value   Fat  Saturated Fats  \
# 0  chocolate pudding fat free            105   0.3             0.0
# 1             tapioca pudding            143   4.3             1.1
# 2    tapioca pudding fat free            105   0.4             0.1
# 3                rice pudding            122   2.4             1.4
# 4                corn pudding            328  12.6             6.3
#
#    Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  Sugars  Protein  \
# 0                  0.00                 0.000           23.6    17.8      2.2
# 1                  2.80                 0.088           23.9    16.4      2.1
# 2                  0.08                 0.067           23.9    15.9      1.6
# 3                  0.60                 0.100           20.8    13.1      3.6
# 4                  3.90                 1.400           42.4    16.5     11.1
#
#    Dietary Fiber  ...  Vitamin K  Calcium   Copper   Iron  Magnesium  \
# ...

# %%
food_5 = pd.read_csv("../data/FOOD-DATA-GROUP5.csv")
food_5 = food_5.drop(["Unnamed: 0", "Unnamed: 0.1", "Nutrition Density"], axis=1)
food_5.head()
# Out:
#                      food  Caloric Value    Fat  Saturated Fats  \
# 0  margarine with yoghurt             88    9.8             1.9
# 1   sunflower seed butter             99    8.8             0.7
# 2            hazelnut oil            120   13.6             1.0
# 3       menhaden fish oil           1966  218.0            66.3
# 4      cod liver fish oil            123   13.6             3.1
#
#    Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  Sugars  Protein  \
# 0                   5.6                   2.0          0.073     0.0    0.058
# 1                   6.2                   1.6          3.700     1.7    2.800
# 2                  10.6                   1.4          0.000     0.0    0.000
# 3                  58.2                  74.5          0.000     0.0    0.000
# 4                   6.4                   3.1          0.000     0.0    0.000
#
#    Dietary Fiber  ...  Vitamin K  Calcium  Copper   Iron  Magnesium  \
# ...

# %% [markdown]
# ## Creando dataset a usar en chatbot

# %%
food_data = pd.concat(
    [food_1, food_2, food_3, food_3, food_4, food_5],
    ignore_index=True
)

# %%
print(food_data.shape)
# Out:
# (2966, 34)

# %%
food_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2966 entries, 0 to 2965
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   food                  2966 non-null   str
#  1   Caloric Value         2966 non-null   int64
#  2   Fat                   2966 non-null   float64
#  3   Saturated Fats        2966 non-null   float64
#  4   Monounsaturated Fats  2966 non-null   float64
#  5   Polyunsaturated Fats  2966 non-null   float64
#  6   Carbohydrates         2966 non-null   float64
#  7   Sugars                2966 non-null   float64
#  8   Protein               2966 non-null   float64
#  9   Dietary Fiber         2966 non-null   float64
#  10  Cholesterol           2966 non-null   float64
#  11  Sodium                2966 non-null   float64
#  12  Water                 2966 non-null   float64
#  13  Vitamin A             2966 non-null   float64
#  14  Vitamin B1            2966 non-null   float64
# ...

# %%
food_data.head()
# Out:
#                                food  Caloric Value   Fat  Saturated Fats  \
# 0                      cream cheese             51   5.0             2.9
# 1                 neufchatel cheese            215  19.4            10.9
# 2  requeijao cremoso light catupiry             49   3.6             2.3
# 3                    ricotta cheese             30   2.0             1.3
# 4              cream cheese low fat             30   2.3             1.4
#
#    Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  Sugars  Protein  \
# 0                   1.3                 0.200            0.8   0.500      0.9
# 1                   4.9                 0.800            3.1   2.700      7.8
# 2                   0.9                 0.000            0.9   3.400      0.8
# 3                   0.5                 0.002            1.5   0.091      1.5
# 4                   0.6                 0.042            1.2   0.900      1.2
#
# ...

# %%
print(food_data.duplicated().sum())
# Out:
# 571

# %%
food_data = food_data.drop_duplicates()

# %%
print(food_data.duplicated().sum())
# Out:
# 0

# %%
print(food_data.shape)
# Out:
# (2395, 34)
